# %%
from sympy import *
from IPython.display import display

# переменные
x1, x2, t = var('x1 x2 t', real=True)

# константы
rho, rho_a, gamma, theta = symbols('rho rho_a gamma theta')
f, W, g, c, Pa, h = symbols('f W g c Pa h')
e11, e12, e22 = symbols('epsilon_11, epsilon_12, epsilon_22')

h = 0

# константы
Ak, Al = var('A_k, A_l')
Bk, Bl = var('B_k, B_l')
Ck, Cl = var('C_k, C_l')

# базисные функции
N_k, N_l = symbols('N_k, N_l')
#N_k = Ak * x1 + Bk * x2 + Ck
#N_l = Al * x1 + Bl * x2 + Cl

# коэффициенты
a_k, a_mk, a_2mk = symbols('a_k, a_{m+k}, a_{2m+k}')

# выражения
#N_11, N_22, N_12, N_p = symbols('N_11 N_22 N_12 N_p')
N_11 = 2 * e11 * Derivative(q1, x1)
N_12 = e12 * (Derivative(q1, x2) + Derivative(q2, x1))
N_22 = 2 * e22 * Derivative(q2, x2)
N_p = rho * g * H**2 / 2 + H * Pa

# misc
k = Symbol("k")
M = Symbol("M")

# функции
#H, q1, q2 = symbols('H q1 q2')

q1 = Sum(a_k(t) * N_k(k), (k, 1, M))
q2 = Sum(a_mk(t) * N_k(k), (k, 1, M))
H = Sum(a_2mk(t) * N_k(k), (k, 1, M))

init_printing(use_latex='mathjax')

# уравнения
eq1 = Derivative(q1, x1) + Derivative(q2, x2) + Derivative(rho * H, t)
eq2 = Derivative(q1, t) + Derivative((q1**2 / H), x1) + Derivative(((q1 * q2) / H), x2) - Derivative((N_11 - N_p), x1) - Derivative(N_12, x2) - f * q2 - (gamma**2 * rho_a * W**2 * cos(theta)) + (g/c**2) * (1/rho) * (q1 * sqrt(q1**2 + q2**2) / H**2) - Pa * Derivative(H, x1) - (rho * g * H) * Derivative(h, x1)
eq3 = Derivative(q2, t) + Derivative(((q1 * q2) / H), x1) + Derivative((q2**2 / H), x2) - Derivative((N_22 - N_p), x2) - Derivative(N_12, x2) + f * q1 - (gamma**2 * rho_a * W**2 * sin(theta)) + (g/c**2) * (1/rho) * (q2 * sqrt(q1**2 + q2**2) / H**2) - Pa * Derivative(H, x2) - (rho * g * H) * Derivative(h, x2)

# %%
eq1
# Out:
#   ⎛    M                    ⎞      ⎛  M              ⎞      ⎛  M
#   ⎜   ___                   ⎟      ⎜ ___             ⎟      ⎜ ___
#   ⎜   ╲                     ⎟      ⎜ ╲               ⎟      ⎜ ╲
# ∂ ⎜    ╲   Nₖ(k)⋅a_{2m+k}(t)⎟    ∂ ⎜  ╲   Nₖ(k)⋅aₖ(t)⎟    ∂ ⎜  ╲   Nₖ(k)⋅a_{m+
# ──⎜ρ⋅  ╱                    ⎟ + ───⎜  ╱              ⎟ + ───⎜  ╱
# ∂t⎜   ╱                     ⎟   ∂x₁⎜ ╱               ⎟   ∂x₂⎜ ╱
#   ⎜   ‾‾‾                   ⎟      ⎜ ‾‾‾             ⎟      ⎜ ‾‾‾
#   ⎝  k = 1                  ⎠      ⎝k = 1            ⎠      ⎝k = 1
#
#      ⎞
#      ⎟
#      ⎟
# k}(t)⎟
#      ⎟
#      ⎟
#      ⎟
#      ⎠

# %%
eq1 = Integral(Mul(eq1, N_l), x1, x2)
eq1
# Out:
# ⌠ ⌠
# ⎮ ⎮    ⎛  ⎛    M                    ⎞      ⎛  M              ⎞      ⎛  M
# ⎮ ⎮    ⎜  ⎜   ___                   ⎟      ⎜ ___             ⎟      ⎜ ___
# ⎮ ⎮    ⎜  ⎜   ╲                     ⎟      ⎜ ╲               ⎟      ⎜ ╲
# ⎮ ⎮    ⎜∂ ⎜    ╲   Nₖ(k)⋅a_{2m+k}(t)⎟    ∂ ⎜  ╲   Nₖ(k)⋅aₖ(t)⎟    ∂ ⎜  ╲   Nₖ(
# ⎮ ⎮ Nₗ⋅⎜──⎜ρ⋅  ╱                    ⎟ + ───⎜  ╱              ⎟ + ───⎜  ╱
# ⎮ ⎮    ⎜∂t⎜   ╱                     ⎟   ∂x₁⎜ ╱               ⎟   ∂x₂⎜ ╱
# ⎮ ⎮    ⎜  ⎜   ‾‾‾                   ⎟      ⎜ ‾‾‾             ⎟      ⎜ ‾‾‾
# ⎮ ⎮    ⎝  ⎝  k = 1                  ⎠      ⎝k = 1            ⎠      ⎝k = 1
# ⌡ ⌡
#
#
#              ⎞⎞
#              ⎟⎟
#              ⎟⎟
# k)⋅a_{m+k}(t)⎟⎟
#              ⎟⎟ d(x₁) d(x₂)
#              ⎟⎟
#              ⎟⎟
#              ⎠⎠

# %%
simplify(eq1)
# Out:
# ⌠ ⌠
# ⎮ ⎮    ⎛   ⎛        M        ⎞      ⎛             M        ⎞     ⎛
# ⎮ ⎮    ⎜   ⎜       ___       ⎟      ⎜            ___       ⎟     ⎜
# ⎮ ⎮    ⎜   ⎜       ╲         ⎟      ⎜            ╲         ⎟     ⎜
# ⎮ ⎮    ⎜ ∂ ⎜        ╲   Nₖ(k)⎟    ∂ ⎜             ╲   Nₖ(k)⎟   ∂ ⎜
# ⎮ ⎮ Nₗ⋅⎜───⎜aₖ(t)⋅  ╱        ⎟ + ───⎜a_{m+k}(t)⋅  ╱        ⎟ + ──⎜ρ⋅a_{2m+k}(t
# ⎮ ⎮    ⎜∂x₁⎜       ╱         ⎟   ∂x₂⎜            ╱         ⎟   ∂t⎜
# ⎮ ⎮    ⎜   ⎜       ‾‾‾       ⎟      ⎜            ‾‾‾       ⎟     ⎜
# ⎮ ⎮    ⎝   ⎝      k = 1      ⎠      ⎝           k = 1      ⎠     ⎝
# ⌡ ⌡
#
#
#     M        ⎞⎞
#    ___       ⎟⎟
#    ╲         ⎟⎟
#     ╲   Nₖ(k)⎟⎟
# )⋅  ╱        ⎟⎟ d(x₁) d(x₂)
#    ╱         ⎟⎟
#    ‾‾‾       ⎟⎟
#   k = 1      ⎠⎠

# %%
eq2
# Out:
#
#
#
#
#
#
#         ⎛  M                    ⎞                         M
#         ⎜ ___                   ⎟                        ___
#         ⎜ ╲                     ⎟                        ╲
#       ∂ ⎜  ╲   Nₖ(k)⋅a_{2m+k}(t)⎟    2  2                 ╲   Nₖ(k)⋅a_{m+k}(t)
# - Pa⋅───⎜  ╱                    ⎟ - W ⋅γ ⋅ρₐ⋅cos(θ) - f⋅  ╱
#      ∂x₁⎜ ╱                     ⎟                        ╱
#         ⎜ ‾‾‾                   ⎟                        ‾‾‾
#         ⎝k = 1                  ⎠                       k = 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 M                          ⎛    ⎛   ⎛  M              ⎞      ⎛
#                ___                         ⎜    ⎜   ⎜ ___             ⎟      ⎜
#                ╲                           ⎜    ⎜   ⎜ ╲               ⎟      ⎜
#         d       ╲   Nₖ(k)⋅a_{2m+k}(t)    ∂ ⎜    ⎜ ∂ ⎜  ╲   Nₖ(k)⋅aₖ(t)⎟    ∂ ⎜
#  - g⋅ρ⋅───(h)⋅  ╱                     - ───⎜ε₁₂⋅⎜───⎜  ╱              ⎟ + ───⎜
#        dx₁     ╱                        ∂x₂⎜    ⎜∂x₂⎜ ╱               ⎟   ∂x₁⎜
#                ‾‾‾                         ⎜    ⎜   ⎜ ‾‾‾             ⎟      ⎜
#               k = 1                        ⎝    ⎝   ⎝k = 1            ⎠      ⎝
#
#
#
#
#
#
#
#
#                                ⎛                     2 ⎞
#                                ⎜  ⎛  M              ⎞  ⎟      ⎛⎛  M
#                                ⎜  ⎜ ___             ⎟  ⎟      ⎜⎜ ___
#                                ⎜  ⎜ ╲               ⎟  ⎟      ⎜⎜ ╲
#                                ⎜  ⎜  ╲   Nₖ(k)⋅aₖ(t)⎟  ⎟      ⎜⎜  ╲   Nₖ(k)⋅aₖ
#   M                   ⎞⎞⎞      ⎜  ⎜  ╱              ⎟  ⎟      ⎜⎜  ╱
#  ___                  ⎟⎟⎟      ⎜  ⎜ ╱               ⎟  ⎟      ⎜⎜ ╱
#  ╲                    ⎟⎟⎟      ⎜  ⎜ ‾‾‾             ⎟  ⎟      ⎜⎜ ‾‾‾
#   ╲   Nₖ(k)⋅a_{m+k}(t)⎟⎟⎟    ∂ ⎜  ⎝k = 1            ⎠  ⎟    ∂ ⎜⎝k = 1
#   ╱                   ⎟⎟⎟ + ───⎜───────────────────────⎟ + ───⎜───────────────
#  ╱                    ⎟⎟⎟   ∂x₁⎜  M                    ⎟   ∂x₂⎜           M
#  ‾‾‾                  ⎟⎟⎟      ⎜ ___                   ⎟      ⎜          ___
# k = 1                 ⎠⎠⎠      ⎜ ╲                     ⎟      ⎜          ╲
#                                ⎜  ╲   Nₖ(k)⋅a_{2m+k}(t)⎟      ⎜           ╲
#                                ⎜  ╱                    ⎟      ⎜           ╱
#                                ⎜ ╱                     ⎟      ⎜          ╱
#                                ⎜ ‾‾‾                   ⎟      ⎜          ‾‾‾
#                                ⎝k = 1                  ⎠      ⎝         k = 1
#
#
#
#                                   ⎛
#    ⎞   M                   ⎞      ⎜
#    ⎟  ___                  ⎟      ⎜
#    ⎟  ╲                    ⎟      ⎜
# (t)⎟   ╲   Nₖ(k)⋅a_{m+k}(t)⎟      ⎜
#    ⎟⋅  ╱                   ⎟      ⎜       M                                ⎛
#    ⎟  ╱                    ⎟      ⎜      ___                               ⎜ _
#    ⎟  ‾‾‾                  ⎟      ⎜      ╲                                 ⎜ ╲
#    ⎠ k = 1                 ⎟    ∂ ⎜       ╲   Nₖ(k)⋅a_{2m+k}(t)          ∂ ⎜
# ───────────────────────────⎟ - ───⎜- Pa⋅  ╱                     + 2⋅ε₁₁⋅───⎜
#                            ⎟   ∂x₁⎜      ╱                              ∂x₁⎜ ╱
#                            ⎟      ⎜      ‾‾‾                               ⎜ ‾
#                            ⎟      ⎝     k = 1                              ⎝k
# Nₖ(k)⋅a_{2m+k}(t)          ⎟
#                            ⎟
#                            ⎟
#                            ⎟
#                            ⎠
#
#
#
#                                                 2⎞
#                        ⎛  M                    ⎞ ⎟
#                        ⎜ ___                   ⎟ ⎟
#                        ⎜ ╲                     ⎟ ⎟
#                        ⎜  ╲   Nₖ(k)⋅a_{2m+k}(t)⎟ ⎟
# M              ⎞   g⋅ρ⋅⎜  ╱                    ⎟ ⎟     ⎛  M              ⎞   g
# __             ⎟       ⎜ ╱                     ⎟ ⎟     ⎜ ___             ⎟
#                ⎟       ⎜ ‾‾‾                   ⎟ ⎟     ⎜ ╲               ⎟
# ╲   Nₖ(k)⋅aₖ(t)⎟       ⎝k = 1                  ⎠ ⎟   ∂ ⎜  ╲   Nₖ(k)⋅aₖ(t)⎟
# ╱              ⎟ - ──────────────────────────────⎟ + ──⎜  ╱              ⎟ + ─
#                ⎟                 2               ⎟   ∂t⎜ ╱               ⎟
# ‾‾             ⎟                                 ⎟     ⎜ ‾‾‾             ⎟
# = 1            ⎠                                 ⎠     ⎝k = 1            ⎠
#
#
#
#
#
#
#
#            __________________________________________________
#           ╱                    2                           2
#          ╱  ⎛  M              ⎞    ⎛  M                   ⎞     M
#         ╱   ⎜ ___             ⎟    ⎜ ___                  ⎟    ___
#        ╱    ⎜ ╲               ⎟    ⎜ ╲                    ⎟    ╲
#       ╱     ⎜  ╲   Nₖ(k)⋅aₖ(t)⎟    ⎜  ╲   Nₖ(k)⋅a_{m+k}(t)⎟     ╲   Nₖ(k)⋅aₖ(t
# ⋅    ╱      ⎜  ╱              ⎟  + ⎜  ╱                   ⎟  ⋅  ╱
#     ╱       ⎜ ╱               ⎟    ⎜ ╱                    ⎟    ╱
#    ╱        ⎜ ‾‾‾             ⎟    ⎜ ‾‾‾                  ⎟    ‾‾‾
#  ╲╱         ⎝k = 1            ⎠    ⎝k = 1                 ⎠   k = 1
# ──────────────────────────────────────────────────────────────────────────────
#                                                      2
#                             ⎛  M                    ⎞
#                             ⎜ ___                   ⎟
#                             ⎜ ╲                     ⎟
#                         2   ⎜  ╲   Nₖ(k)⋅a_{2m+k}(t)⎟
#                        c ⋅ρ⋅⎜  ╱                    ⎟
#                             ⎜ ╱                     ⎟
#                             ⎜ ‾‾‾                   ⎟
#                             ⎝k = 1                  ⎠
#
#
#
#
#
#
# )
#
#
#
#
# ─

# %%
eq2 = Integral(Mul(eq2, N_l), x1, x2)
eq2
# Out:
# ⌠ ⌠
# ⎮ ⎮    ⎛
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎜        ⎛  M                    ⎞                         M
# ⎮ ⎮    ⎜        ⎜ ___                   ⎟                        ___
# ⎮ ⎮    ⎜        ⎜ ╲                     ⎟                        ╲
# ⎮ ⎮    ⎜      ∂ ⎜  ╲   Nₖ(k)⋅a_{2m+k}(t)⎟    2  2                 ╲   Nₖ(k)⋅a_
# ⎮ ⎮ Nₗ⋅⎜- Pa⋅───⎜  ╱                    ⎟ - W ⋅γ ⋅ρₐ⋅cos(θ) - f⋅  ╱
# ⎮ ⎮    ⎜     ∂x₁⎜ ╱                     ⎟                        ╱
# ⎮ ⎮    ⎜        ⎜ ‾‾‾                   ⎟                        ‾‾‾
# ⎮ ⎮    ⎜        ⎝k = 1                  ⎠                       k = 1
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎝
# ⌡ ⌡
#
#
#
#
#
#
#
#
#                         M                          ⎛    ⎛   ⎛  M
#                        ___                         ⎜    ⎜   ⎜ ___
#                        ╲                           ⎜    ⎜   ⎜ ╲
# {m+k}(t)        d       ╲   Nₖ(k)⋅a_{2m+k}(t)    ∂ ⎜    ⎜ ∂ ⎜  ╲   Nₖ(k)⋅aₖ(t)
#          - g⋅ρ⋅───(h)⋅  ╱                     - ───⎜ε₁₂⋅⎜───⎜  ╱
#                dx₁     ╱                        ∂x₂⎜    ⎜∂x₂⎜ ╱
#                        ‾‾‾                         ⎜    ⎜   ⎜ ‾‾‾
#                       k = 1                        ⎝    ⎝   ⎝k = 1
#
#
#
#
#
#
#
#
#
#
#                                        ⎛                     2 ⎞
#                                        ⎜  ⎛  M              ⎞  ⎟      ⎛⎛  M
#                                        ⎜  ⎜ ___             ⎟  ⎟      ⎜⎜ ___
#                                        ⎜  ⎜ ╲               ⎟  ⎟      ⎜⎜ ╲
#                                        ⎜  ⎜  ╲   Nₖ(k)⋅aₖ(t)⎟  ⎟      ⎜⎜  ╲
# ⎞      ⎛  M                   ⎞⎞⎞      ⎜  ⎜  ╱              ⎟  ⎟      ⎜⎜  ╱
# ⎟      ⎜ ___                  ⎟⎟⎟      ⎜  ⎜ ╱               ⎟  ⎟      ⎜⎜ ╱
# ⎟      ⎜ ╲                    ⎟⎟⎟      ⎜  ⎜ ‾‾‾             ⎟  ⎟      ⎜⎜ ‾‾‾
# ⎟    ∂ ⎜  ╲   Nₖ(k)⋅a_{m+k}(t)⎟⎟⎟    ∂ ⎜  ⎝k = 1            ⎠  ⎟    ∂ ⎜⎝k = 1
# ⎟ + ───⎜  ╱                   ⎟⎟⎟ + ───⎜───────────────────────⎟ + ───⎜───────
# ⎟   ∂x₁⎜ ╱                    ⎟⎟⎟   ∂x₁⎜  M                    ⎟   ∂x₂⎜
# ⎟      ⎜ ‾‾‾                  ⎟⎟⎟      ⎜ ___                   ⎟      ⎜
# ⎠      ⎝k = 1                 ⎠⎠⎠      ⎜ ╲                     ⎟      ⎜
#                                        ⎜  ╲   Nₖ(k)⋅a_{2m+k}(t)⎟      ⎜
#                                        ⎜  ╱                    ⎟      ⎜
#                                        ⎜ ╱                     ⎟      ⎜
#                                        ⎜ ‾‾‾                   ⎟      ⎜
#                                        ⎝k = 1                  ⎠      ⎝
#
#
#
#
#
#                                           ⎛
#            ⎞   M                   ⎞      ⎜
#            ⎟  ___                  ⎟      ⎜
#            ⎟  ╲                    ⎟      ⎜
# Nₖ(k)⋅aₖ(t)⎟   ╲   Nₖ(k)⋅a_{m+k}(t)⎟      ⎜
#            ⎟⋅  ╱                   ⎟      ⎜       M
#            ⎟  ╱                    ⎟      ⎜      ___
#            ⎟  ‾‾‾                  ⎟      ⎜      ╲
#            ⎠ k = 1                 ⎟    ∂ ⎜       ╲   Nₖ(k)⋅a_{2m+k}(t)
# ───────────────────────────────────⎟ - ───⎜- Pa⋅  ╱                     + 2⋅ε₁
#     M                              ⎟   ∂x₁⎜      ╱
#    ___                             ⎟      ⎜      ‾‾‾
#    ╲                               ⎟      ⎝     k = 1
#     ╲   Nₖ(k)⋅a_{2m+k}(t)          ⎟
#     ╱                              ⎟
#    ╱                               ⎟
#    ‾‾‾                             ⎟
#   k = 1                            ⎠
#
#
#
#
#
#                                                         2⎞
#                                ⎛  M                    ⎞ ⎟
#                                ⎜ ___                   ⎟ ⎟
#                                ⎜ ╲                     ⎟ ⎟
#                                ⎜  ╲   Nₖ(k)⋅a_{2m+k}(t)⎟ ⎟
#      ⎛  M              ⎞   g⋅ρ⋅⎜  ╱                    ⎟ ⎟     ⎛  M
#      ⎜ ___             ⎟       ⎜ ╱                     ⎟ ⎟     ⎜ ___
#      ⎜ ╲               ⎟       ⎜ ‾‾‾                   ⎟ ⎟     ⎜ ╲
#    ∂ ⎜  ╲   Nₖ(k)⋅aₖ(t)⎟       ⎝k = 1                  ⎠ ⎟   ∂ ⎜  ╲   Nₖ(k)⋅aₖ
# ₁⋅───⎜  ╱              ⎟ - ──────────────────────────────⎟ + ──⎜  ╱
#   ∂x₁⎜ ╱               ⎟                 2               ⎟   ∂t⎜ ╱
#      ⎜ ‾‾‾             ⎟                                 ⎟     ⎜ ‾‾‾
#      ⎝k = 1            ⎠                                 ⎠     ⎝k = 1
#
#
#
#
#
#
#
#
#
#                    __________________________________________________
#                   ╱                    2                           2
#                  ╱  ⎛  M              ⎞    ⎛  M                   ⎞     M
#                 ╱   ⎜ ___             ⎟    ⎜ ___                  ⎟    ___
#                ╱    ⎜ ╲               ⎟    ⎜ ╲                    ⎟    ╲
#               ╱     ⎜  ╲   Nₖ(k)⋅aₖ(t)⎟    ⎜  ╲   Nₖ(k)⋅a_{m+k}(t)⎟     ╲   Nₖ
#    ⎞   g⋅    ╱      ⎜  ╱              ⎟  + ⎜  ╱                   ⎟  ⋅  ╱
#    ⎟        ╱       ⎜ ╱               ⎟    ⎜ ╱                    ⎟    ╱
#    ⎟       ╱        ⎜ ‾‾‾             ⎟    ⎜ ‾‾‾                  ⎟    ‾‾‾
# (t)⎟     ╲╱         ⎝k = 1            ⎠    ⎝k = 1                 ⎠   k = 1
#    ⎟ + ───────────────────────────────────────────────────────────────────────
#    ⎟                                                         2
#    ⎟                                ⎛  M                    ⎞
#    ⎠                                ⎜ ___                   ⎟
#                                     ⎜ ╲                     ⎟
#                                 2   ⎜  ╲   Nₖ(k)⋅a_{2m+k}(t)⎟
#                                c ⋅ρ⋅⎜  ╱                    ⎟
#                                     ⎜ ╱                     ⎟
#                                     ⎜ ‾‾‾                   ⎟
#                                     ⎝k = 1                  ⎠
#
#
#
#          ⎞
#          ⎟
#          ⎟
#          ⎟
#          ⎟
# (k)⋅aₖ(t)⎟
#          ⎟
#          ⎟
#          ⎟
#          ⎟
# ─────────⎟ d(x₁) d(x₂)
#          ⎟
#          ⎟
#          ⎟
#          ⎟
#          ⎟
#          ⎟
#          ⎟
#          ⎟
#          ⎠

# %%
simplify(eq2)
# Out:
# ⌠ ⌠
# ⎮ ⎮    ⎛
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎜        ⎛              M        ⎞
# ⎮ ⎮    ⎜        ⎜             ___       ⎟
# ⎮ ⎮    ⎜        ⎜             ╲         ⎟
# ⎮ ⎮    ⎜      ∂ ⎜              ╲   Nₖ(k)⎟    2  2             ⎛
# ⎮ ⎮ Nₗ⋅⎜- Pa⋅───⎜a_{2m+k}(t)⋅  ╱        ⎟ - W ⋅γ ⋅ρₐ⋅cos(θ) - ⎜f⋅a_{m+k}(t) +
# ⎮ ⎮    ⎜     ∂x₁⎜             ╱         ⎟                     ⎝
# ⎮ ⎮    ⎜        ⎜             ‾‾‾       ⎟
# ⎮ ⎮    ⎜        ⎝            k = 1      ⎠
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎜
# ⎮ ⎮    ⎝
# ⌡ ⌡
#
#
#
#
#
#
#
#
#                           M              ⎛    ⎛   ⎛        M        ⎞      ⎛
#                          ___             ⎜    ⎜   ⎜       ___       ⎟      ⎜
#                          ╲               ⎜    ⎜   ⎜       ╲         ⎟      ⎜
#                  d    ⎞   ╲   Nₖ(k)    ∂ ⎜    ⎜ ∂ ⎜        ╲   Nₖ(k)⎟    ∂ ⎜
# g⋅ρ⋅a_{2m+k}(t)⋅───(h)⎟⋅  ╱         - ───⎜ε₁₂⋅⎜───⎜aₖ(t)⋅  ╱        ⎟ + ───⎜a_
#                 dx₁   ⎠  ╱            ∂x₂⎜    ⎜∂x₂⎜       ╱         ⎟   ∂x₁⎜
#                          ‾‾‾             ⎜    ⎜   ⎜       ‾‾‾       ⎟      ⎜
#                         k = 1            ⎝    ⎝   ⎝      k = 1      ⎠      ⎝
#
#
#
#
#
#
#
#
#
#
#                                                      ⎛         M        ⎞
#                                                      ⎜        ___       ⎟
#                                                      ⎜        ╲         ⎟
#                                                      ⎜  2      ╲   Nₖ(k)⎟
#            M        ⎞⎞⎞     ⎛        M        ⎞      ⎜aₖ (t)⋅  ╱        ⎟
#           ___       ⎟⎟⎟     ⎜       ___       ⎟      ⎜        ╱         ⎟
#           ╲         ⎟⎟⎟     ⎜       ╲         ⎟      ⎜        ‾‾‾       ⎟
#            ╲   Nₖ(k)⎟⎟⎟   ∂ ⎜        ╲   Nₖ(k)⎟    ∂ ⎜       k = 1      ⎟    ∂
# {m+k}(t)⋅  ╱        ⎟⎟⎟ + ──⎜aₖ(t)⋅  ╱        ⎟ + ───⎜──────────────────⎟ + ──
#           ╱         ⎟⎟⎟   ∂t⎜       ╱         ⎟   ∂x₁⎝   a_{2m+k}(t)    ⎠   ∂x
#           ‾‾‾       ⎟⎟⎟     ⎜       ‾‾‾       ⎟
#          k = 1      ⎠⎠⎠     ⎝      k = 1      ⎠
#
#
#
#
#
#
#
#
#
#                                      ⎛
#  ⎛                   M        ⎞      ⎜
#  ⎜                  ___       ⎟      ⎜
#  ⎜                  ╲         ⎟      ⎜
#  ⎜                   ╲   Nₖ(k)⎟      ⎜
#  ⎜aₖ(t)⋅a_{m+k}(t)⋅  ╱        ⎟      ⎜                   M
#  ⎜                  ╱         ⎟      ⎜                  ___
#  ⎜                  ‾‾‾       ⎟      ⎜                  ╲
#  ⎜                 k = 1      ⎟    ∂ ⎜                   ╲   Nₖ(k)          ∂
# ─⎜────────────────────────────⎟ - ───⎜- Pa⋅a_{2m+k}(t)⋅  ╱         + 2⋅ε₁₁⋅───
# ₂⎝        a_{2m+k}(t)         ⎠   ∂x₁⎜                  ╱                  ∂x₁
#                                      ⎜                  ‾‾‾
#                                      ⎝                 k = 1
#
#
#
#
#
#
#
#
#                                                                      _________
#                                                     2⎞              ╱
#                                        ⎛  M        ⎞ ⎟             ╱
#                                        ⎜ ___       ⎟ ⎟            ╱
#                                        ⎜ ╲         ⎟ ⎟           ╱
#                                   2    ⎜  ╲   Nₖ(k)⎟ ⎟          ╱     ⎛  2
# ⎛        M        ⎞   g⋅ρ⋅a_{2m+k} (t)⋅⎜  ╱        ⎟ ⎟   g⋅    ╱      ⎝aₖ (t)
# ⎜       ___       ⎟                    ⎜ ╱         ⎟ ⎟        ╱
# ⎜       ╲         ⎟                    ⎜ ‾‾‾       ⎟ ⎟       ╱
# ⎜        ╲   Nₖ(k)⎟                    ⎝k = 1      ⎠ ⎟     ╲╱
# ⎜aₖ(t)⋅  ╱        ⎟ - ───────────────────────────────⎟ + ─────────────────────
# ⎜       ╱         ⎟                  2               ⎟
# ⎜       ‾‾‾       ⎟                                  ⎟
# ⎝      k = 1      ⎠                                  ⎠
#                                                                         2
#                                                                        c ⋅ρ⋅a_
#
#
#
#
#
#
# ______________________________      ⎞
#                             2       ⎟
#                ⎛  M        ⎞        ⎟
#                ⎜ ___       ⎟        ⎟
#                ⎜ ╲         ⎟        ⎟
#          2   ⎞ ⎜  ╲   Nₖ(k)⎟        ⎟
# + a_{m+k} (t)⎠⋅⎜  ╱        ⎟  ⋅aₖ(t)⎟
#                ⎜ ╱         ⎟        ⎟
#                ⎜ ‾‾‾       ⎟        ⎟
#                ⎝k = 1      ⎠        ⎟
# ────────────────────────────────────⎟ d(x₁) d(x₂)
#              M                      ⎟
#             ___                     ⎟
#             ╲                       ⎟
#       2      ╲   Nₖ(k)              ⎟
# {2m+k} (t)⋅  ╱                      ⎟
#             ╱                       ⎟
#             ‾‾‾                     ⎟
#            k = 1                    ⎠
