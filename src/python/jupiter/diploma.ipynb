# %%
from sympy import *
from IPython.display import display

# misc
k, l = symbols("k l")
M = Symbol("M")

# переменные
x1, x2, t = var('x1 x2 t', real=True)

# константы
rho, rho_a, gamma, theta = symbols('rho rho_a gamma theta')
f, W, g, c, Pa, h = symbols('f W g c Pa h')
e11, e12, e22 = symbols('epsilon_11, epsilon_12, epsilon_22')

#rho = 1000
#c = 10
#g = 9.832
#gamma = 0.04472135955
#W = 10
theta = 0
#Pa = 100
#rho_a = 1.2754
f = 0
#f = 0.973 * 10e-4
h = 0

e11 = 0
e12 = 0
e22 = 0

# константы для базисных функций
Ak, Al = var('A_k, A_l')
Bk, Bl = var('B_k, B_l')
Ck, Cl = var('C_k, C_l')

# базисные функции
N_k = Function('N_k') 
N_l = Function('N_l')

#N_k = Ak * x1 + Bk * x2 + Ck
#N_l = Al * x1 + Bl * x2 + Cl

# коэффициенты
a_k, a_mk, a_2mk = symbols('a_k, a_{m+k}, a_{2m+k}')

# функции
#q1 = Sum(a_k(t) * N_k(x1, x2, k), (k, 1, M))
#q2 = Sum(a_mk(t) * N_k(x1, x2, k), (k, 1, M))
#H = Sum(a_2mk(t) * N_k(x1, x2, k), (k, 1, M))

H, q1, q2 = symbols('H q1 q2')

# выражения
N_11, N_22, N_12, N_p = symbols('N_11 N_22 N_12 N_p')
N_11 = 2 * e11 * Derivative(q1, x1)
N_12 = e12 * (Derivative(q1, x2) + Derivative(q2, x1))
N_22 = 2 * e22 * Derivative(q2, x2)
N_p = rho * g * H**2 / 2 + H * Pa



init_printing(use_latex='mathjax')

# уравнения
eq1 = Derivative(q1(x1, x2, t), x1) + Derivative(q2(x1, x2, t), x2) + Derivative(rho * H(x1, x2, t), t)
eq2 = Derivative(q1, t) - (gamma**2 * rho_a * W**2 * cos(theta)) - Pa * Derivative(H, x1) - (rho * g * H) * Derivative(h, x1)
#Derivative((q1**2 / H), x1) + 
#Derivative(((q1 * q2) / H), x2)
#- Derivative((N_11 - N_p), x1) 
#- Derivative(N_12, x2) 
#- f * q2 
#+ (g/c**2) * (1/rho) * (q1 * sqrt(q1**2 + q2**2) / H**2) 

eq3 = Derivative(q2, t) - (gamma**2 * rho_a * W**2 * sin(theta)) - Pa * Derivative(H, x2) - (rho * g * H) * Derivative(h, x2)
#+ Derivative(((q1 * q2) / H), x1) 
#+ Derivative((q2**2 / H), x2) 
#- Derivative((N_22 - N_p), x2) 
#- Derivative(N_12, x2) + f * q1 
#+ (g/c**2) * (1/rho) * (q2 * sqrt(q1**2 + q2**2) / H**2)

# %%
eq1
# Out:
# ∂                     ∂                    ∂
# ──(ρ⋅H(x₁, x₂, t)) + ───(q₁(x₁, x₂, t)) + ───(q₂(x₁, x₂, t))
# ∂t                   ∂x₁                  ∂x₂

# %%
eq1.subs([
    (q1(x1, x2, t), Sum(a_k(t) * N_k(x1, x2, k), (k, 1, M))),
    (q2(x1, x2, t), Sum(a_mk(t) * N_k(x1, x2, k), (k, 1, M))),
    (H(x1, x2, t), Sum(a_2mk(t) * N_k(x1, x2, k), (k, 1, M)))
])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-075d74e76a53> in <module>()
#       2     (q1(x1, x2, t), Sum(a_k(t) * N_k(x1, x2, k), (k, 1, M))),
#       3
# ----> 4     (H(x1, x2, t), Sum(a_2mk(t) * N_k(x1, x2, k), (k, 1, M)))
#       5 ])
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sympy/core/basic.py in subs(self, *args, **kwargs)
#     914             rv = self
#     915             for old, new in sequence:
# --> 916                 rv = rv._subs(old, new, **kwargs)
#     917                 if not isinstance(rv, Basic):
#     918                     break
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      91             def wrapper(*args, **kwargs):
#      92                 try:
# ...

# %%
eq1 = eq1.doit()
eq1 = Sum(Integral(Mul(eq1, N_l(x1, x2, l)), x1, x2), (l, 1, M))
#eq1 = Integral(Mul(eq1, N_l(x1, x2, k)), x1, x2)
eq1
# Out:
#   M
# _____
# ╲
#  ╲    ⌠ ⌠
#   ╲   ⎮ ⎮ ⎛  ∂                   ∂                    ∂                ⎞
#    ╲  ⎮ ⎮ ⎜ρ⋅──(H(x₁, x₂, t)) + ───(q₁(x₁, x₂, t)) + ───(q₂(x₁, x₂, t))⎟⋅Nₗ(x₁
#    ╱  ⎮ ⎮ ⎝  ∂t                 ∂x₁                  ∂x₂               ⎠
#   ╱   ⌡ ⌡
#  ╱
# ╱
# ‾‾‾‾‾
# l = 1
#
#
#
#
#
#
# , x₂, l) d(x₁) d(x₂)

# %%
eq1 = expand(eq1)
eq1 = simplify(eq1)
#eq1 = factor(eq1)
eq1
# Out:
#   ∂                   ∂                    ∂
# ρ⋅──(H(x₁, x₂, t)) + ───(q₁(x₁, x₂, t)) + ───(q₂(x₁, x₂, t))
#   ∂t                 ∂x₁                  ∂x₂

# %%
right_part = Integral(N_l(x1, x2, k) * Sum(Integral(rho * N_l(x1, x2, l) * Derivative(a_2mk(t), t) * Sum(N_k(x1, x2, k), (k, 1, M)), x1, x2),  (l, 1, M)), x1, x2)
left_part = solve(eq1, right_part)
right_part
# Out:
# ⌠ ⌠
# ⎮ ⎮                  M
# ⎮ ⎮               _______
# ⎮ ⎮               ╲
# ⎮ ⎮                ╲      ⌠ ⌠
# ⎮ ⎮                 ╲     ⎮ ⎮                                   M
# ⎮ ⎮                  ╲    ⎮ ⎮                                  ___
# ⎮ ⎮                   ╲   ⎮ ⎮                                  ╲
# ⎮ ⎮                    ╲  ⎮ ⎮                 d                 ╲   Nₖ(x₁, x₂,
# ⎮ ⎮ Nₗ(x₁, x₂, k)⋅     ╱  ⎮ ⎮ ρ⋅Nₗ(x₁, x₂, l)⋅──(a_{2m+k}(t))⋅  ╱
# ⎮ ⎮                   ╱   ⎮ ⎮                 dt               ╱
# ⎮ ⎮                  ╱    ⎮ ⎮                                  ‾‾‾
# ⎮ ⎮                 ╱     ⎮ ⎮                                 k = 1
# ⎮ ⎮                ╱      ⌡ ⌡
# ⎮ ⎮               ╱
# ⎮ ⎮               ‾‾‾‾‾‾‾
# ⎮ ⎮                l = 1
# ⌡ ⌡
#
#
#
#
#
#
#
#
#
#  k)
#     d(x₁) d(x₂) d(x₁) d(x₂)

# %%
left_part
# Out:
# ⎡  ⌠ ⌠
# ⎢  ⎮ ⎮                  M
# ⎢  ⎮ ⎮               ________
# ⎢  ⎮ ⎮               ╲
# ⎢  ⎮ ⎮                ╲       ⌠ ⌠
# ⎢  ⎮ ⎮                 ╲      ⎮ ⎮                       M
# ⎢  ⎮ ⎮                  ╲     ⎮ ⎮                      ____
# ⎢  ⎮ ⎮                   ╲    ⎮ ⎮                      ╲
# ⎢  ⎮ ⎮                    ╲   ⎮ ⎮                       ╲    ∂
# ⎢  ⎮ ⎮                     ╲  ⎮ ⎮                        ╲  ───(Nₖ(x₁, x₂, k))
# ⎢- ⎮ ⎮ Nₗ(x₁, x₂, k)⋅      ╱  ⎮ ⎮ Nₗ(x₁, x₂, l)⋅aₖ(t)⋅   ╱  ∂x₁
# ⎢  ⎮ ⎮                    ╱   ⎮ ⎮                       ╱
# ⎢  ⎮ ⎮                   ╱    ⎮ ⎮                      ╱
# ⎢  ⎮ ⎮                  ╱     ⎮ ⎮                      ‾‾‾‾
# ⎢  ⎮ ⎮                 ╱      ⎮ ⎮                     k = 1
# ⎢  ⎮ ⎮                ╱       ⌡ ⌡
# ⎢  ⎮ ⎮               ╱
# ⎢  ⎮ ⎮               ‾‾‾‾‾‾‾‾
# ⎢  ⎮ ⎮                l = 1
# ⎣  ⌡ ⌡
#
#                            ⌠ ⌠
#                            ⎮ ⎮                  M
# ...

# %%
eq2
# Out:
# ⌠ ⌠
# ⎮ ⎮                   M
# ⎮ ⎮               _________
# ⎮ ⎮               ╲
# ⎮ ⎮                ╲        ⌠ ⌠
# ⎮ ⎮                 ╲       ⎮ ⎮                         ⌠ ⌠
# ⎮ ⎮                  ╲      ⎮ ⎮                         ⎮ ⎮                 M
# ⎮ ⎮                   ╲     ⎮ ⎮                         ⎮ ⎮                ___
# ⎮ ⎮                    ╲    ⎮ ⎮                         ⎮ ⎮                ╲
# ⎮ ⎮                     ╲   ⎮ ⎮                         ⎮ ⎮                 ╲
# ⎮ ⎮                      ╲  ⎮ ⎮   2  2                  ⎮ ⎮                  ╲
# ⎮ ⎮ Nₗ(x₁, x₂, k)⋅       ╱  ⎮ ⎮ -W ⋅γ ⋅ρₐ⋅Nₗ(x₁, x₂, l)⋅⎮ ⎮ Nₗ(x₁, x₂, k)⋅   ╱
# ⎮ ⎮                     ╱   ⎮ ⎮                         ⎮ ⎮                 ╱
# ⎮ ⎮                    ╱    ⎮ ⎮                         ⎮ ⎮                ╱
# ⎮ ⎮                   ╱     ⎮ ⎮                         ⎮ ⎮                ‾‾‾
# ⎮ ⎮                  ╱      ⎮ ⎮                         ⎮ ⎮               l =
# ...

# %%
eq2 = eq2.doit()
eq2 = Sum(Integral(Mul(eq2, N_l(x1, x2, l)), x1, x2), (l, 1, M))
eq2 = Integral(Mul(eq2, N_l(x1, x2, k)), x1, x2)
eq2
# Out:
# ⌠ ⌠
# ⎮ ⎮                     M
# ⎮ ⎮               ______________
# ⎮ ⎮               ╲
# ⎮ ⎮                ╲             ⌠ ⌠
# ⎮ ⎮                 ╲            ⎮ ⎮                         ⌠ ⌠
# ⎮ ⎮                  ╲           ⎮ ⎮                         ⎮ ⎮
# ⎮ ⎮                   ╲          ⎮ ⎮                         ⎮ ⎮
# ⎮ ⎮                    ╲         ⎮ ⎮                         ⎮ ⎮
# ⎮ ⎮                     ╲        ⎮ ⎮                         ⎮ ⎮
# ⎮ ⎮                      ╲       ⎮ ⎮                         ⎮ ⎮
# ⎮ ⎮                       ╲      ⎮ ⎮                         ⎮ ⎮
# ⎮ ⎮                        ╲     ⎮ ⎮                         ⎮ ⎮
# ⎮ ⎮                         ╲    ⎮ ⎮                         ⎮ ⎮
# ⎮ ⎮                          ╲   ⎮ ⎮                         ⎮ ⎮
# ⎮ ⎮                           ╲  ⎮ ⎮   2  2                  ⎮ ⎮
# ⎮ ⎮ Nₗ(x₁, x₂, k)⋅            ╱  ⎮ ⎮ -W ⋅γ ⋅ρₐ⋅Nₗ(x₁, x₂, l)⋅⎮ ⎮ Nₗ(x₁, x₂, k)
# ...

# %%
eq2 = expand(eq2)
eq2 = simplify(eq2)
#eq2 = factor(eq2)
eq2
# Out:
#           ⌠ ⌠
#           ⎮ ⎮                     M
#           ⎮ ⎮               ______________
#           ⎮ ⎮               ╲
#           ⎮ ⎮                ╲             ⌠ ⌠
#           ⎮ ⎮                 ╲            ⎮ ⎮               ⌠ ⌠
#           ⎮ ⎮                  ╲           ⎮ ⎮               ⎮ ⎮
#           ⎮ ⎮                   ╲          ⎮ ⎮               ⎮ ⎮
#           ⎮ ⎮                    ╲         ⎮ ⎮               ⎮ ⎮
#           ⎮ ⎮                     ╲        ⎮ ⎮               ⎮ ⎮
#           ⎮ ⎮                      ╲       ⎮ ⎮               ⎮ ⎮
#           ⎮ ⎮                       ╲      ⎮ ⎮               ⎮ ⎮
#           ⎮ ⎮                        ╲     ⎮ ⎮               ⎮ ⎮
#           ⎮ ⎮                         ╲    ⎮ ⎮               ⎮ ⎮
#           ⎮ ⎮                          ╲   ⎮ ⎮               ⎮ ⎮
#   2  2    ⎮ ⎮                           ╲  ⎮ ⎮               ⎮ ⎮
# -W ⋅γ ⋅ρₐ⋅⎮ ⎮ Nₗ(x₁, x₂, k)⋅            ╱  ⎮ ⎮ Nₗ(x₁, x₂, l)⋅⎮ ⎮ Nₗ(x₁, x₂, k)
# ...

# %%
right_part = Integral(N_l(x1, x2, k) * Sum(Integral(N_l(x1, x2, l) * Derivative(a_k(t), t) * Sum(N_k(x1, x2, k), (k, 1, M)), x1, x2),  (l, 1, M)), x1, x2)
left_part = solve(eq2, right_part)
right_part
# Out:
# ⌠ ⌠
# ⎮ ⎮                  M
# ⎮ ⎮               _______
# ⎮ ⎮               ╲
# ⎮ ⎮                ╲      ⌠ ⌠
# ⎮ ⎮                 ╲     ⎮ ⎮                           M
# ⎮ ⎮                  ╲    ⎮ ⎮                          ___
# ⎮ ⎮                   ╲   ⎮ ⎮                          ╲
# ⎮ ⎮                    ╲  ⎮ ⎮               d           ╲   Nₖ(x₁, x₂, k)
# ⎮ ⎮ Nₗ(x₁, x₂, k)⋅     ╱  ⎮ ⎮ Nₗ(x₁, x₂, l)⋅──(aₖ(t))⋅  ╱                 d(x₁
# ⎮ ⎮                   ╱   ⎮ ⎮               dt         ╱
# ⎮ ⎮                  ╱    ⎮ ⎮                          ‾‾‾
# ⎮ ⎮                 ╱     ⎮ ⎮                         k = 1
# ⎮ ⎮                ╱      ⌡ ⌡
# ⎮ ⎮               ╱
# ⎮ ⎮               ‾‾‾‾‾‾‾
# ⎮ ⎮                l = 1
# ⌡ ⌡
#
#
#
#
#
#
#
#
#
#
# ) d(x₂) d(x₁) d(x₂)

# %%
left_part
# Out:
# []

# %%
eq3
# Out:
#
#
#
#
#
#
#         ⎛  M                            ⎞                M
#         ⎜ ___                           ⎟               ___
#         ⎜ ╲                             ⎟               ╲
#       ∂ ⎜  ╲   Nₖ(x₁, x₂, k)⋅a_{2m+k}(t)⎟        d       ╲   Nₖ(x₁, x₂, k)⋅a_{
# - Pa⋅───⎜  ╱                            ⎟ - g⋅ρ⋅───(0)⋅  ╱
#      ∂x₂⎜ ╱                             ⎟       dx₂     ╱
#         ⎜ ‾‾‾                           ⎟               ‾‾‾
#         ⎝k = 1                          ⎠              k = 1
#
#
#
#
#
#
#
#
#                        ⎛                                2⎞
#                        ⎜⎛  M                           ⎞ ⎟      ⎛⎛  M
#                        ⎜⎜ ___                          ⎟ ⎟      ⎜⎜ ___
#                        ⎜⎜ ╲                            ⎟ ⎟      ⎜⎜ ╲
#                        ⎜⎜  ╲   Nₖ(x₁, x₂, k)⋅a_{m+k}(t)⎟ ⎟      ⎜⎜  ╲   Nₖ(x₁,
#                        ⎜⎜  ╱                           ⎟ ⎟      ⎜⎜  ╱
# ...

# %%
eq3 = eq3.doit()
eq3 = Sum(Integral(Mul(eq3, N_l(x1, x2, l)), x1, x2), (l, 1, M))
eq3 = Integral(Mul(eq3, N_l(x1, x2, k)), x1, x2)
eq3
# Out:
# ⌠ ⌠
# ⎮ ⎮                     M
# ⎮ ⎮               _____________
# ⎮ ⎮               ╲
# ⎮ ⎮                ╲            ⌠ ⌠
# ⎮ ⎮                 ╲           ⎮ ⎮ ⎛
# ⎮ ⎮                  ╲          ⎮ ⎮ ⎜
# ⎮ ⎮                   ╲         ⎮ ⎮ ⎜
# ⎮ ⎮                    ╲        ⎮ ⎮ ⎜
# ⎮ ⎮                     ╲       ⎮ ⎮ ⎜
# ⎮ ⎮                      ╲      ⎮ ⎮ ⎜                                        M
# ⎮ ⎮                       ╲     ⎮ ⎮ ⎜    ⎛  M                            ⎞  __
# ⎮ ⎮                        ╲    ⎮ ⎮ ⎜    ⎜ ___                           ⎟  ╲
# ⎮ ⎮                         ╲   ⎮ ⎮ ⎜    ⎜ ╲                             ⎟   ╲
# ⎮ ⎮                          ╲  ⎮ ⎮ ⎜    ⎜  ╲   Nₖ(x₁, x₂, k)⋅a_{2m+k}(t)⎟
# ⎮ ⎮ Nₗ(x₁, x₂, k)⋅           ╱  ⎮ ⎮ ⎜g⋅ρ⋅⎜  ╱                            ⎟⋅
# ⎮ ⎮                         ╱   ⎮ ⎮ ⎜    ⎜ ╱                             ⎟   ╱
# ⎮ ⎮                        ╱    ⎮ ⎮ ⎜    ⎜ ‾‾‾                           ⎟  ╱
# ...

# %%
eq3 = expand(eq3)
eq3 = simplify(eq3)
#eq3 = factor(eq3)
eq3
# Out:
#
#
#
#
#
#
# ⌠ ⌠
# ⎮ ⎮                  M
# ⎮ ⎮               _______
# ⎮ ⎮               ╲
# ⎮ ⎮                ╲      ⌠ ⌠
# ⎮ ⎮                 ╲     ⎮ ⎮                                M
# ⎮ ⎮                  ╲    ⎮ ⎮                               ___
# ⎮ ⎮                   ╲   ⎮ ⎮                               ╲
# ⎮ ⎮                    ╲  ⎮ ⎮               d                ╲   Nₖ(x₁, x₂, k)
# ⎮ ⎮ Nₗ(x₁, x₂, k)⋅     ╱  ⎮ ⎮ Nₗ(x₁, x₂, l)⋅──(a_{m+k}(t))⋅  ╱
# ⎮ ⎮                   ╱   ⎮ ⎮               dt              ╱
# ⎮ ⎮                  ╱    ⎮ ⎮                               ‾‾‾
# ⎮ ⎮                 ╱     ⎮ ⎮                              k = 1
# ⎮ ⎮                ╱      ⌡ ⌡
# ⎮ ⎮               ╱
# ⎮ ⎮               ‾‾‾‾‾‾‾
# ⎮ ⎮                l = 1
# ⌡ ⌡
#
#
#
#
#
#
#
#
#
#
#
#                            ⌠ ⌠
#                            ⎮ ⎮                   M
#                            ⎮ ⎮               _________
#                            ⎮ ⎮               ╲
# ...

# %%
right_part = Integral(N_l(x1, x2, k) * Sum(Integral(N_l(x1, x2, l) * Derivative(a_mk(t), t) * Sum(N_k(x1, x2, k), (k, 1, M)), x1, x2),  (l, 1, M)), x1, x2)
left_part = solve(eq3, right_part)
right_part
# Out:
# ⌠ ⌠
# ⎮ ⎮                  M
# ⎮ ⎮               _______
# ⎮ ⎮               ╲
# ⎮ ⎮                ╲      ⌠ ⌠
# ⎮ ⎮                 ╲     ⎮ ⎮                                M
# ⎮ ⎮                  ╲    ⎮ ⎮                               ___
# ⎮ ⎮                   ╲   ⎮ ⎮                               ╲
# ⎮ ⎮                    ╲  ⎮ ⎮               d                ╲   Nₖ(x₁, x₂, k)
# ⎮ ⎮ Nₗ(x₁, x₂, k)⋅     ╱  ⎮ ⎮ Nₗ(x₁, x₂, l)⋅──(a_{m+k}(t))⋅  ╱
# ⎮ ⎮                   ╱   ⎮ ⎮               dt              ╱
# ⎮ ⎮                  ╱    ⎮ ⎮                               ‾‾‾
# ⎮ ⎮                 ╱     ⎮ ⎮                              k = 1
# ⎮ ⎮                ╱      ⌡ ⌡
# ⎮ ⎮               ╱
# ⎮ ⎮               ‾‾‾‾‾‾‾
# ⎮ ⎮                l = 1
# ⌡ ⌡
#
#
#
#
#
#
#
#
#
#
#  d(x₁) d(x₂) d(x₁) d(x₂)

# %%
left_part
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢  ⌠ ⌠
# ⎢  ⎮ ⎮                   M
# ⎢  ⎮ ⎮               _________
# ⎢  ⎮ ⎮               ╲
# ⎢  ⎮ ⎮                ╲        ⌠ ⌠
# ⎢  ⎮ ⎮                 ╲       ⎮ ⎮                              M
# ⎢  ⎮ ⎮                  ╲      ⎮ ⎮                             ____
# ⎢  ⎮ ⎮                   ╲     ⎮ ⎮                             ╲
# ⎢  ⎮ ⎮                    ╲    ⎮ ⎮                              ╲    ∂
# ⎢  ⎮ ⎮                     ╲   ⎮ ⎮                       2       ╲  ───(Nₖ(x₁,
# ⎢  ⎮ ⎮                      ╲  ⎮ ⎮ -Nₗ(x₁, x₂, l)⋅a_{m+k} (t)⋅   ╱  ∂x₂
# ⎢- ⎮ ⎮ Nₗ(x₁, x₂, k)⋅       ╱  ⎮ ⎮                              ╱
# ⎢  ⎮ ⎮                     ╱   ⎮ ⎮                             ╱
# ⎢  ⎮ ⎮                    ╱    ⎮ ⎮                             ‾‾‾‾
# ⎢  ⎮ ⎮                   ╱     ⎮ ⎮                            k = 1
# ⎢  ⎮ ⎮                  ╱      ⎮ ⎮ ───────────────────────────────────────────
# ...

# %%
с11, c12, c13 = symbols('c_11, c_12, c_13')

Derivative(a_k(t), t) - с11
# Out:
#        d
# -c₁₁ + ──(aₖ(t))
#        dt
